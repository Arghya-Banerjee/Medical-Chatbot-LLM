# %%
import os
os.chdir("../")

# %%
# %pwd
# Out:
# 'e:\\GEN AI\\Medical-Chatbot-LLM'

# %%
from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
# Extract data from pdf
def load_pdf_files(path):
    loader = DirectoryLoader(
        path=path,
        glob="*.pdf",
        loader_cls=PyPDFLoader
    )

    documents = loader.load()
    return documents

# %%
extracted_data = load_pdf_files("data")

# %%
len(extracted_data)
# Out:
# 637

# %%
from typing import List
from langchain_core.documents import Document

def filter_to_minimal_docs(docs: List[Document]) -> List[Document]:
    minimal_docs = []
    for doc in docs:
        src = doc.metadata.get("source")
        minimal_docs.append(
            Document(
                page_content=doc.page_content,
                metadata={"source": src}
            )
        )

    return minimal_docs

# %%
minimal_docs = filter_to_minimal_docs(extracted_data)

# %%
# minimal_docs

# %%
# Split docs into smaller chunks

def text_split(minimal_docs):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=500,
        chunk_overlap=20
    )
    texts_chunk = text_splitter.split_documents(minimal_docs)
    return texts_chunk

# %%
texts_chunk = text_split(minimal_docs)

# %%
len(texts_chunk)
# Out:
# 5859

# %%
from langchain_huggingface import HuggingFaceEmbeddings

def download_embeddings():
    model_name = "sentence-transformers/all-MiniLM-L6-v2"
    embeddings = HuggingFaceEmbeddings(
        model_name = model_name
    )
    return embeddings

embedding = download_embeddings()

# %%
embedding
# Out:
# HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2', cache_folder=None, model_kwargs={}, encode_kwargs={}, query_encode_kwargs={}, multi_process=False, show_progress=False)

# %%
from dotenv import load_dotenv
load_dotenv()

PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

os.environ["PINECONE_API_KEY"] = PINECONE_API_KEY
os.environ["GEMINI_API_KEY"] = GEMINI_API_KEY

# %%
from pinecone import Pinecone, ServerlessSpec

pc = Pinecone(
    api_key=PINECONE_API_KEY,
)

# %%
idx = pc.create_index(
    name="medical-chatbot",
    dimension=384,
    metric="cosine",
    spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    )
)
# Out:
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 idx = pc.create_index(
#       2     name="medical-chatbot",
#       3     dimension=384,
#       4     metric="cosine",
#       5     spec=ServerlessSpec(
#       6         cloud="aws",
#       7         region="us-east-1"
#       8     )
#       9 )
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\pinecone\pinecone.py:499, in create_index(self, name, spec, dimension, metric, timeout, deletion_protection, vector_type, tags)
#     488 else:
#     489     # Otherwise, get host url from describe_index using the index name
#     490     index_host = self.db.index._get_host(name)
#     492 return _Index(
#     493     host=index_host,
#     494     api_key=api_key,
#     495     pool_threads=pt,
#     496     openapi_config=openapi_config,
#     497     source_tag=self.config.source_tag,
#     498     **kwargs,
# --> 499 )
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\pinecone\utils\require_kwargs.py:26, in wrapper(*args, **kwargs)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\pinecone\db_control\resources\sync\index.py:95, in create(self, name, spec, dimension, metric, timeout, deletion_protection, vector_type, tags)
#      84         return IndexModel(resp)
#      85     return self.__poll_describe_index_until_ready(name, timeout)
#      87 @require_kwargs
#      88 def create_for_model(
#      89     self,
#      90     *,
#      91     name: str,
#      92     cloud: Union["CloudProvider", str],
#      93     region: Union["AwsRegion", "GcpRegion", "AzureRegion", str],
#      94     embed: Union["IndexEmbed", "CreateIndexForModelEmbedTypedDict"],
# ---> 95     tags: Optional[Dict[str, str]] = None,
#      96     deletion_protection: Optional[Union["DeletionProtection", str]] = "disabled",
#      97     timeout: Optional[int] = None,
#      98 ) -> IndexModel:
#      99     req = PineconeDBControlRequestFactory.create_index_for_model_request(
#     100         name=name,
#     101         cloud=cloud,
#    (...)    105         deletion_protection=deletion_protection,
#     106     )
#     107     resp = self._index_api.create_index_for_model(req)
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)    100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\pinecone\core\openapi\db_control\api\manage_indexes_api.py:375, in __create_index(self, create_index_request, x_pinecone_api_version, **kwargs)
#     353 def __create_index_for_model(
#     354     self, create_index_for_model_request, **kwargs: ExtraOpenApiKwargsTypedDict
#     355 ):
#     356     """Create an index with integrated embedding  # noqa: E501
#     357
#     358     Create an index with integrated embedding.  With this type of index, you provide source text, and Pinecone uses a [hosted embedding model](https://docs.pinecone.io/guides/index-data/create-an-index#embedding-models) to convert the text automatically during [upsert](https://docs.pinecone.io/reference/api/2025-01/data-plane/upsert_records) and [search](https://docs.pinecone.io/reference/api/2025-01/data-plane/search_records).  For guidance and examples, see [Create an index](https://docs.pinecone.io/guides/index-data/create-an-index#integrated-embedding).  # noqa: E501
#     359     This method makes a synchronous HTTP request by default. To make an
#     360     asynchronous HTTP request, please pass async_req=True
#     361
#     362     >>> thread = api.create_index_for_model(create_index_for_model_request, async_req=True)
#     363     >>> result = thread.get()
#     364
#     365     Args:
#     366         create_index_for_model_request (CreateIndexForModelRequest): The desired configuration for the index and associated embedding model.
#     367
#     368     Keyword Args:
#     369         _return_http_data_only (bool): response data without head status
#     370             code and headers. Default is True.
#     371         _preload_content (bool): if False, the urllib3.HTTPResponse object
#     372             will be returned without reading/decoding response data.
#     373             Default is True.
#     374         _request_timeout (int/float/tuple): timeout setting for this request. If
# --> 375             one number provided, it will be total request timeout. It can also
#     376             be a pair (tuple) of (connection, read) timeouts.
#     377             Default is None.
#     378         _check_input_type (bool): specifies if type checking
#     379             should be done one the data sent to the server.
#     380             Default is True.
#     381         _check_return_type (bool): specifies if type checking
#     382             should be done one the data received from the server.
#     383             Default is True.
#     384         async_req (bool): execute request asynchronously
#     385
#     386     Returns:
#     387         IndexModel
#     388             If the method is called asynchronously, returns the request
#     389             thread.
#     390     """
#     391     kwargs = self._process_openapi_kwargs(kwargs)
#     392     kwargs["create_index_for_model_request"] = create_index_for_model_request
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)    129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\pinecone\openapi_support\api_client.py:320, in call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     285     return self.threadpool_executor.submit(
#     286         self.__call_api,
#     287         resource_path,
#    (...)    302         _check_type,
#     303     )
#     305 if not async_req:
#     306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
# --> 320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\pinecone\openapi_support\api_client.py:185, in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\pinecone\openapi_support\api_client.py:173, in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     161 url = build_request_url(
#     162     config=config,
#     163     processed_path_params=path_params_tuple,
#     164     resource_path=resource_path,
#     165     _host=_host,
#     166 )
#     168 try:
#     169     # perform request and return response
#     170     response_data = self.request(
#     171         method,
#     172         url,
# --> 173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\pinecone\openapi_support\api_client.py:400, in request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#    (...)    393         body=body,
#     394     )
#     395 elif method == "PUT":
#     396     return self.rest_client.PUT(
#     397         url,
#     398         query_params=query_params,
#     399         headers=headers,
# --> 400         post_params=post_params,
#     401         _preload_content=_preload_content,
#     402         _request_timeout=_request_timeout,
#     403         body=body,
#     404     )
#     405 elif method == "PATCH":
#     406     return self.rest_client.PATCH(
#     407         url,
#     408         query_params=query_params,
#    (...)    413         body=body,
#     414     )
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:270, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      46     if 500 <= r.status <= 599:
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'content-type': 'text/plain; charset=utf-8', 'access-control-allow-origin': '*', 'vary': 'origin, access-control-request-method, access-control-request-headers', 'access-control-expose-headers': '*', 'x-pinecone-api-version': '2025-10', 'x-cloud-trace-context': '7b0ff1758e30a15f5713ff726c49ab8b', 'date': 'Thu, 11 Dec 2025 07:29:31 GMT', 'server': 'Google Frontend', 'Content-Length': '85', 'Via': '1.1 google', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'})
# HTTP response body: {"error":{"code":"ALREADY_EXISTS","message":"Resource  already exists"},"status":409}

# %%
from langchain_pinecone import PineconeVectorStore

docsearch = PineconeVectorStore.from_documents(
    documents=texts_chunk,
    embedding=embedding,
    index_name="medical-chatbot"
)

# %%
retriever = docsearch.as_retriever(search_type="similarity", search_kwargs={"k": 3})

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['PineconeVectorStore', 'HuggingFaceEmbeddings'], vectorstore=<langchain_pinecone.vectorstores.PineconeVectorStore object at 0x000001D3807EA490>, search_kwargs={'k': 3})

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

chatModel = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0.5,
    api_key=GEMINI_API_KEY
)

# %%
from langchain_classic.chains import create_retrieval_chain
from langchain_classic.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate

# %%
system_prompt = (
    "You are a Medical Assisstant for answer questions. "
    "Use the following pieces of retrieved context to answer the question. "
    "If you dont know the answer say that you dont know it. "
    "Use three sentences maximum and keep the answers concise. \n\n"
    "{context}"
)

prompt = ChatPromptTemplate(
    [
        ("system", system_prompt),
        ("human", "{input}")
    ]
)

# %%
question_answer_chain = create_stuff_documents_chain(chatModel, prompt)
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# %%
response = rag_chain.invoke({"input": "What is Gigantism?"})
print(response["answer"])
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_google_genai\chat_models.py:2958, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    2957 try:
# -> 2958     response: GenerateContentResponse = self.client.models.generate_content(
#    2959         **request,
#    2960     )
#    2961 except ClientError as e:
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\google\genai\models.py:5230, in Models.generate_content(self, model, contents, config)
#    5229 i += 1
# -> 5230 response = self._generate_content(
#    5231     model=model, contents=contents, config=parsed_config
#    5232 )
#    5234 function_map = _extra_utils.get_function_map(parsed_config)
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\google\genai\models.py:4012, in Models._generate_content(self, model, contents, config)
#    4010 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4012 response = self._api_client.request(
#    4013     'post', path, request_dict, http_options
#    4014 )
#    4016 if config is not None and getattr(
#    4017     config, 'should_return_http_response', None
#    4018 ):
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\google\genai\_api_client.py:1388, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1385 http_request = self._build_request(
#    1386     http_method, path, request_dict, http_options
#    1387 )
# -> 1388 response = self._request(http_request, http_options, stream=False)
#    1389 response_body = (
#    1390     response.response_stream[0] if response.response_stream else ''
#    1391 )
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\google\genai\_api_client.py:1222, in BaseApiClient._request(self, http_request, http_options, stream)
#    1221     retry = tenacity.Retrying(**retry_kwargs)
# -> 1222     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1224 return self._retry(self._request_once, http_request, stream)
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     186 if self.last_attempt.failed:
# --> 187     raise self.last_attempt.result()
#     188 raise self
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\google\genai\_api_client.py:1201, in BaseApiClient._request_once(self, http_request, stream)
#    1194 response = self._httpx_client.request(
#    1195     method=http_request.method,
#    1196     url=http_request.url,
#    (...)   1199     timeout=http_request.timeout,
#    1200 )
# -> 1201 errors.APIError.raise_for_response(response)
#    1202 return HttpResponse(
#    1203     response.headers, response if stream else [response.text]
#    1204 )
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\google\genai\errors.py:121, in APIError.raise_for_response(cls, response)
#     119   response_json = response.body_segments[0].get('error', {})
# --> 121 cls.raise_error(response.status_code, response_json, response)
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\google\genai\errors.py:146, in APIError.raise_error(cls, status_code, response_json, response)
#     145 if 400 <= status_code < 500:
# --> 146   raise ClientError(status_code, response_json, response)
#     147 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.0-flash\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash\nPlease retry in 16.097308474s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerMinute-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '16s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 response = rag_chain.invoke({"input": "What is Gigantism?"})
#       2 print(response["answer"])
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_core\runnables\base.py:5548, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5541 @override
#    5542 def invoke(
#    5543     self,
#    (...)   5546     **kwargs: Any | None,
#    5547 ) -> Output:
# -> 5548     return self.bound.invoke(
#    5549         input,
#    5550         self._merge_configs(config),
#    5551         **{**self.kwargs, **kwargs},
#    5552     )
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_core\runnables\base.py:3143, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3141                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3142             else:
# -> 3143                 input_ = context.run(step.invoke, input_, config)
#    3144 # finish the root run
#    3145 except BaseException as e:
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_core\runnables\passthrough.py:507, in RunnableAssign.invoke(self, input, config, **kwargs)
#     500 @override
#     501 def invoke(
#     502     self,
#    (...)    505     **kwargs: Any,
#     506 ) -> dict[str, Any]:
# --> 507     return self._call_with_config(self._invoke, input, config, **kwargs)
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_core\runnables\base.py:2058, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2054     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2055     with set_config_context(child_config) as context:
#    2056         output = cast(
#    2057             "Output",
# -> 2058             context.run(
#    2059                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2060                 func,
#    2061                 input_,
#    2062                 config,
#    2063                 run_manager,
#    2064                 **kwargs,
#    2065             ),
#    2066         )
#    2067 except BaseException as e:
#    2068     run_manager.on_chain_error(e)
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_core\runnables\config.py:433, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     431 if run_manager is not None and accepts_run_manager(func):
#     432     kwargs["run_manager"] = run_manager
# --> 433 return func(input, **kwargs)
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_core\runnables\passthrough.py:493, in RunnableAssign._invoke(self, value, run_manager, config, **kwargs)
#     488     msg = "The input to RunnablePassthrough.assign() must be a dict."
#     489     raise ValueError(msg)  # noqa: TRY004
#     491 return {
#     492     **value,
# --> 493     **self.mapper.invoke(
#     494         value,
#     495         patch_config(config, callbacks=run_manager.get_child()),
#     496         **kwargs,
#     497     ),
#     498 }
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_core\runnables\base.py:3867, in RunnableParallel.invoke(self, input, config, **kwargs)
#    3862     with get_executor_for_config(config) as executor:
#    3863         futures = [
#    3864             executor.submit(_invoke_step, step, input, config, key)
#    3865             for key, step in steps.items()
#    3866         ]
# -> 3867         output = {
#    3868             key: future.result()
#    3869             for key, future in zip(steps, futures, strict=False)
#    3870         }
#    3871 # finish the root run
#    3872 except BaseException as e:
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_core\runnables\base.py:3868, in <dictcomp>(.0)
#    3862     with get_executor_for_config(config) as executor:
#    3863         futures = [
#    3864             executor.submit(_invoke_step, step, input, config, key)
#    3865             for key, step in steps.items()
#    3866         ]
#    3867         output = {
# -> 3868             key: future.result()
#    3869             for key, future in zip(steps, futures, strict=False)
#    3870         }
#    3871 # finish the root run
#    3872 except BaseException as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_core\runnables\base.py:3851, in RunnableParallel.invoke.<locals>._invoke_step(step, input_, config, key)
#    3845 child_config = patch_config(
#    3846     config,
#    3847     # mark each step as a child run
#    3848     callbacks=run_manager.get_child(f"map:key:{key}"),
#    3849 )
#    3850 with set_config_context(child_config) as context:
# -> 3851     return context.run(
#    3852         step.invoke,
#    3853         input_,
#    3854         child_config,
#    3855     )
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_core\runnables\base.py:5548, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5541 @override
#    5542 def invoke(
#    5543     self,
#    (...)   5546     **kwargs: Any | None,
#    5547 ) -> Output:
# -> 5548     return self.bound.invoke(
#    5549         input,
#    5550         self._merge_configs(config),
#    5551         **{**self.kwargs, **kwargs},
#    5552     )
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_core\runnables\base.py:3143, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3141                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3142             else:
# -> 3143                 input_ = context.run(step.invoke, input_, config)
#    3144 # finish the root run
#    3145 except BaseException as e:
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_google_genai\chat_models.py:2461, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2458         msg = "Tools are already defined.code_execution tool can't be defined"
#    2459         raise ValueError(msg)
# -> 2461 return super().invoke(input, config, stop=stop, **kwargs)
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:398, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)    391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
# --> 398             self.generate_prompt(
#     399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
#     403                 metadata=config.get("metadata"),
#     404                 run_name=config.get("run_name"),
#     405                 run_id=config.pop("run_id", None),
#     406                 **kwargs,
#     407             ).generations[0][0],
#     408         ).message,
#     409     )
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1117, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1108 @override
#    1109 def generate_prompt(
#    1110     self,
#    (...)   1114     **kwargs: Any,
#    1115 ) -> LLMResult:
#    1116     prompt_messages = [p.to_messages() for p in prompts]
# -> 1117     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:927, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     924 for i, m in enumerate(input_messages):
#     925     try:
#     926         results.append(
# --> 927             self._generate_with_cache(
#     928                 m,
#     929                 stop=stop,
#     930                 run_manager=run_managers[i] if run_managers else None,
#     931                 **kwargs,
#     932             )
#     933         )
#     934     except BaseException as e:
#     935         if run_managers:
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1221, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219     result = generate_from_stream(iter(chunks))
#    1220 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221     result = self._generate(
#    1222         messages, stop=stop, run_manager=run_manager, **kwargs
#    1223     )
#    1224 else:
#    1225     result = self._generate(messages, stop=stop, **kwargs)
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_google_genai\chat_models.py:2962, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    2958     response: GenerateContentResponse = self.client.models.generate_content(
#    2959         **request,
#    2960     )
#    2961 except ClientError as e:
# -> 2962     _handle_client_error(e, request)
#    2964 return _response_to_result(response)
#
# File e:\GEN AI\Medical-Chatbot-LLM\venv\Lib\site-packages\langchain_google_genai\chat_models.py:145, in _handle_client_error(e, request)
#     143 model_name = request.get("model", "unknown")
#     144 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 145 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.0-flash' (RESOURCE_EXHAUSTED): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.0-flash\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash\nPlease retry in 16.097308474s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerMinute-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '16s'}]}}
